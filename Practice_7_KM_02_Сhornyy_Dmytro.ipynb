# %% [markdown]
# # **Курс "Програмування на мові Python"**
#
# ##### Викладачі:
# ##### Борисенко Павло Борисович
# ##### Щьоголєв Максим Олегович

# %% [markdown]
# ## **Практичне зайняття №7**
#
# ### Тема: "Перевірка даних. Робота з виключеннями. Регулярні вирази"

# %% [markdown]
# ### **Завдання 1 (1,5 бали)**
#
# Переробити завдання №1 практичної роботи №6 з використанням регулярних виразів.
#
# 1. Створити шаблон регулярного виразу.
#
# 2. За допомогою функції compile() створити об'єкт регулярного виразу.
#
# 3. Всі інші вимоги залишаються такими ж, як і в оригінальному завданні.

# %%
pose_estimation = "[BodyPart:0-(0.55, 0.17) score=0.81 BodyPart:1-(0.49, 0.27) score=0.85 BodyPart:2-(0.41, 0.26) score=0.67 BodyPart:3-(0.33, 0.37) score=0.72 BodyPart:4-(0.36, 0.48) score=0.78 BodyPart:5-(0.58, 0.27) score=0.81 BodyPart:6-(0.65, 0.38) score=0.88 BodyPart:7-(0.62, 0.48) score=0.86 BodyPart:8-(0.43, 0.48) score=0.60 BodyPart:9-(0.43, 0.66) score=0.67 BodyPart:10-(0.53, 0.79) score=0.56 BodyPart:11-(0.53, 0.48) score=0.56 BodyPart:12-(0.59, 0.66) score=0.75 BodyPart:13-(0.49, 0.80) score=0.50 BodyPart:14-(0.54, 0.15) score=0.73 BodyPart:15-(0.56, 0.15) score=0.85 BodyPart:16-(0.48, 0.16) score=0.81 BodyPart:17-(0.83, 0.18) score=0.79]"

import re
points = []
scores = []

points_key = r"\((.+?), (.+?)\)"
scores_key = r"score=(.+?)( |])"

points = [float(i) for j in re.findall(points_key, pose_estimation) for i in j]
scores = [float(i[0]) for i in re.findall(scores_key, pose_estimation)]
print(points)
print(scores)
# Out:
# [0.55, 0.17, 0.49, 0.27, 0.41, 0.26, 0.33, 0.37, 0.36, 0.48, 0.58, 0.27, 0.65, 0.38, 0.62, 0.48, 0.43, 0.48, 0.43, 0.66, 0.53, 0.79, 0.53, 0.48, 0.59, 0.66, 0.49, 0.8, 0.54, 0.15, 0.56, 0.15, 0.48, 0.16, 0.83, 0.18]
# [0.81, 0.85, 0.67, 0.72, 0.78, 0.81, 0.88, 0.86, 0.6, 0.67, 0.56, 0.56, 0.75, 0.5, 0.73, 0.85, 0.81, 0.79]

# %% [markdown]
# ### **Завдання 2 (1,5 бали)**
#
# Написати програму підрахунку коренів квадратного рівняння без попередніх перевірок.
#
# 1. Користувач має вводити коефіцієнти a, b та c з клавіатури.
#
# 2. Програма має обробляти помилки ділення на 0, кореня від'ємного числа та інші, а також виводити відповідні повідомлення у разі виникнення таких помилок.
#
# 3. Якщо рівняння не має коренів, программа має генерувати помилку за допомогою ключового слова raise, а потім обробляти її.
#
# 4. Правильно написана програма при виникненні різних помилок має виводити текст помилки, а також різні повідомлення про те, в чому суть цих помилок. Необроблених помилок бути не повинно.
#
# ### **Перепрошую, не зрозумів, що мається на увазі під "вивести текст помилки". Тому прикріплюю дві програми, як два варіанта - в першій програмі виводиться відповідна помилка з повідомленням. У іншій - просто назва помилки з повідомленням.**

# %%
try:
    a, b, c = (float(input("Enter a: ")), float(input("Enter b: ")), float(input("Enter c: ")))
    D = (b**2) - 4*a*c
    if D < 0:
        raise ArithmeticError
    elif D == 0:
        print("You have one solution: ", round((-b)/2*a, 3))
    else:
        print("You have two solutions: ", round(((-b)+(D**0.5))/2*a, 3), round(((-b)-(D**0.5))/2*a, 3))
except ZeroDivisionError:
    raise ZeroDivisionError("Sorry, but there was divison on zero. a can`t be equal to zero.") from None
except ValueError:
    raise ValueError("Sorry, but you should enter only numbers.") from None
except ArithmeticError:
    raise ArithmeticError("Sorry, but your equation has not roots.") from None
except:
    raise Exception("Some another error occured.") from None
# Out:
# You have one solution:  -2.0

# %%
try:
    a, b, c = (float(input("Enter a: ")), float(input("Enter b: ")), float(input("Enter c: ")))
    D = (b**2) - 4*a*c
    if D < 0:
        raise ArithmeticError
    elif D == 0:
        print("You have one solution: ", round((-b)/2*a, 3))
    else:
        print("You have two solutions: ", round(((-b)+(D**0.5))/2*a, 3), round(((-b)-(D**0.5))/2*a, 3))
except ZeroDivisionError:
    print("ZeroDivisionError:", "Sorry, but there was divison on zero. a can`t be equal to zero.") 
except ValueError:
    print("ValueError:", "Sorry, but you should enter only numbers.") 
except ArithmeticError:
    print("ArithmeticError:", "Sorry, but your equation has not roots.") 
except:
    print("Unknown error", "Some another error occured.")
# Out:
# ArithmeticError: Sorry, but our equation has not roots.
